# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (4.12.3)
# Collecting rank-bm25 (from -r requirements.txt (line 3))
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Collecting fastapi (from -r requirements.txt (line 4))
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (0.1.10)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.7.1)
# Collecting openai (from -r requirements.txt (line 7))
#   Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 13.1 MB/s eta 0:00:00
# Collecting pre-commit (from -r requirements.txt (line 8))
#   Downloading pre_commit-3.6.2-py2.py3-none-any.whl (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.2/204.2 kB 27.5 MB/s eta 0:00:00
# Collecting python-dotenv (from -r requirements.txt (line 9))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: ray in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (2.9.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (2.5.1)
# Collecting slack_bolt (from -r requirements.txt (line 13))
#   Downloading slack_bolt-1.18.1-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.7/194.7 kB 26.5 MB/s eta 0:00:00
# Collecting streamlit (from -r requirements.txt (line 14))
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 97.3 MB/s eta 0:00:00
# Collecting structlog (from -r requirements.txt (line 15))
#   Downloading structlog-24.1.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (0.9.0)
# Collecting tiktoken (from -r requirements.txt (line 17))
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 93.6 MB/s eta 0:00:00
# Collecting asyncpg (from -r requirements.txt (line 20))
#   Downloading asyncpg-0.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 105.0 MB/s eta 0:00:00
# Collecting pgvector (from -r requirements.txt (line 21))
#   Downloading pgvector-0.2.5-py2.py3-none-any.whl (9.6 kB)
# Collecting psycopg[binary,pool] (from -r requirements.txt (line 22))
#   Downloading psycopg-3.1.18-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 kB 28.2 MB/s eta 0:00:00
# Collecting psycopg2-binary (from -r requirements.txt (line 23))
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 102.2 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy[asyncio] in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 24)) (2.0.27)
# Collecting black (from -r requirements.txt (line 27))
#   Downloading black-24.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.0 MB/s eta 0:00:00
# Collecting flake8 (from -r requirements.txt (line 28))
#   Downloading flake8-7.0.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 9.8 MB/s eta 0:00:00
# Collecting Flake8-pyproject (from -r requirements.txt (line 29))
#   Downloading flake8_pyproject-1.2.3-py3-none-any.whl (4.8 kB)
# Collecting isort (from -r requirements.txt (line 30))
#   Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 15.2 MB/s eta 0:00:00
# Collecting pyupgrade (from -r requirements.txt (line 31))
#   Downloading pyupgrade-3.15.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank-bm25->-r requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi->-r requirements.txt (line 4)) (2.6.3)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->-r requirements.txt (line 4))
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->-r requirements.txt (line 4)) (4.10.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.25 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (0.0.25)
# Requirement already satisfied: langchain-core<0.2,>=0.1.28 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (0.1.29)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (0.1.17)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r requirements.txt (line 5)) (8.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->-r requirements.txt (line 7)) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai->-r requirements.txt (line 7))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai->-r requirements.txt (line 7)) (4.66.2)
# Collecting cfgv>=2.0.0 (from pre-commit->-r requirements.txt (line 8))
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Collecting identify>=1.0.0 (from pre-commit->-r requirements.txt (line 8))
#   Downloading identify-2.5.35-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 15.6 MB/s eta 0:00:00
# Collecting nodeenv>=0.11.1 (from pre-commit->-r requirements.txt (line 8))
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit->-r requirements.txt (line 8))
#   Downloading virtualenv-20.25.1-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.5 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (1.0.7)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray->-r requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->-r requirements.txt (line 11)) (1.5.3)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 12)) (4.38.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 12)) (2.1.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 12)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 12)) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 12)) (0.20.3)
# Collecting slack-sdk<4,>=3.25.0 (from slack_bolt->-r requirements.txt (line 13))
#   Downloading slack_sdk-3.27.1-py2.py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.7/285.7 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit->-r requirements.txt (line 14)) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (5.3.3)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (7.0.1)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (5.2)
# Collecting validators<1,>=0.2 (from streamlit->-r requirements.txt (line 14))
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 14))
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 29.1 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 14))
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 111.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r requirements.txt (line 14)) (6.3.2)
# Collecting watchdog>=2.1.5 (from streamlit->-r requirements.txt (line 14))
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->-r requirements.txt (line 17)) (2023.12.25)
# Collecting psycopg-binary==3.1.18 (from psycopg[binary,pool]->-r requirements.txt (line 22))
#   Downloading psycopg_binary-3.1.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 115.0 MB/s eta 0:00:00
# Collecting psycopg-pool (from psycopg[binary,pool]->-r requirements.txt (line 22))
#   Downloading psycopg_pool-3.2.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy[asyncio]->-r requirements.txt (line 24)) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->-r requirements.txt (line 27)) (1.0.0)
# Collecting pathspec>=0.9.0 (from black->-r requirements.txt (line 27))
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->-r requirements.txt (line 27)) (4.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->-r requirements.txt (line 27)) (2.0.1)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8->-r requirements.txt (line 28))
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting pycodestyle<2.12.0,>=2.11.0 (from flake8->-r requirements.txt (line 28))
#   Downloading pycodestyle-2.11.1-py2.py3-none-any.whl (31 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8->-r requirements.txt (line 28))
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.7 MB/s eta 0:00:00
# Collecting tokenize-rt>=5.2.0 (from pyupgrade->-r requirements.txt (line 31))
#   Downloading tokenize_rt-5.2.0-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 5)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 5)) (1.9.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (3.1.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 7)) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 5)) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain->-r requirements.txt (line 5)) (0.9.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 7)) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 7))
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 12.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 7))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 12)) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<8,>=1.4->streamlit->-r requirements.txt (line 14)) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain->-r requirements.txt (line 5)) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r requirements.txt (line 10)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r requirements.txt (line 10)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain->-r requirements.txt (line 5)) (3.9.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nodeenv>=0.11.1->pre-commit->-r requirements.txt (line 8)) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->-r requirements.txt (line 11)) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 4)) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 5)) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14)) (2.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 12)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 12)) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers->-r requirements.txt (line 12)) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers->-r requirements.txt (line 12)) (0.4.2)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->-r requirements.txt (line 8))
#   Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 12)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 12)) (3.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14)) (0.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers->-r requirements.txt (line 12)) (1.3.0)
# Installing collected packages: distlib, watchdog, virtualenv, validators, tokenize-rt, structlog, smmap, slack-sdk, rank-bm25, python-dotenv, pyflakes, pycodestyle, psycopg2-binary, psycopg-pool, psycopg-binary, psycopg, pgvector, pathspec, nodeenv, mccabe, isort, identify, h11, cfgv, asyncpg, tiktoken, starlette, slack_bolt, pyupgrade, pydeck, pre-commit, httpcore, gitdb, flake8, black, httpx, gitpython, Flake8-pyproject, fastapi, openai, streamlit
# Successfully installed Flake8-pyproject-1.2.3 asyncpg-0.29.0 black-24.2.0 cfgv-3.4.0 distlib-0.3.8 fastapi-0.110.0 flake8-7.0.0 gitdb-4.0.11 gitpython-3.1.42 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 identify-2.5.35 isort-5.13.2 mccabe-0.7.0 nodeenv-1.8.0 openai-1.13.3 pathspec-0.12.1 pgvector-0.2.5 pre-commit-3.6.2 psycopg-3.1.18 psycopg-binary-3.1.18 psycopg-pool-3.2.1 psycopg2-binary-2.9.9 pycodestyle-2.11.1 pydeck-0.8.1b0 pyflakes-3.2.0 python-dotenv-1.0.1 pyupgrade-3.15.1 rank-bm25-0.2.2 slack-sdk-3.27.1 slack_bolt-1.18.1 smmap-5.0.1 starlette-0.36.3 streamlit-1.31.1 structlog-24.1.0 tiktoken-0.6.0 tokenize-rt-5.2.0 validators-0.22.0 virtualenv-20.25.1 watchdog-4.0.0

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar  4 23:33:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import matplotlib as plt

# %%
## load data
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/data/SPOTIFY_REVIEWS.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                             review_id       pseudo_author_id  \
# 0           0  14a011a8-7544-47b4-8480-c502af0ac26f  152618553977019693742
# 1           1  bfa8876b-470e-4640-83a7-77427f7f37e8  234382942865437071667
# 2           2  70e8252f-058a-47d9-b066-df9e1571c970  174473604608358796368
# 3           3  672a155a-e81e-4d28-bdeb-a74c031bc072  286593453219054880269
# 4           4  bbc1bf95-ed36-41a1-8b98-0f2e314caea5  167276875678680630145
#
#      author_name                                        review_text  \
# 0  A Google user                                   Use it every day
# 1  A Google user  I enjoy the awesome UI of this app, and it has...
# 2  A Google user                Love it! Especially the new design!
# 3  A Google user              Awesome UI, best music app out there!
# 4  A Google user  As a professional Android developer I'm glad t...
#
#    review_rating  review_likes author_app_version     review_timestamp
# 0              5             1           1.1.0.91  2014-05-27 14:21:48
# 1              5             4           1.1.0.91  2014-05-27 14:36:02
# 2              5             2           1.1.0.91  2014-05-27 14:40:01
# 3              5             1           1.1.0.91  2014-05-27 15:17:20
# 4              5            10           1.1.0.91  2014-05-27 15:26:48

# %%
data['review_id'] = data['review_id'].astype("string")
data['review_text'] = data['review_text'].astype("string")

# %%
data.dropna(inplace=True)

# %%
data.isnull().values.any()
# Out:
# False

# %%
import ray
ray.init()
ray.cluster_resources()
# Out:
# 2024-03-04 23:34:19,195	INFO worker.py:1724 -- Started a local Ray instance.
# {'node:172.28.0.12': 1.0,
#  'GPU': 1.0,
#  'memory': 32299418420.0,
#  'node:__internal_head__': 1.0,
#  'object_store_memory': 16149709209.0,
#  'accelerator_type:T4': 1.0,
#  'CPU': 8.0}

# %%
import os
os.environ['HF_TOKEN'] = "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"
os.environ['QDRANT_TOKEN'] = "p0A0Vug10LFhc7M66v3LUE4hMIACXVj3CRuYk5CsJl6CjxHeDQ9j_g"

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
import numpy as np
from ray.data import ActorPoolStrategy

@ray.remote(num_gpus=1)
class EmbedModels:
    def __init__(self, model_name="jinaai/jina-embeddings-v2-base-en"):
            self.embedding_model = HuggingFaceEmbeddings(
                model_name=model_name,
                model_kwargs={"device": "cuda"},
                encode_kwargs={"device": "cuda", "batch_size": 100})

    def get_embedding(self, batch):
        embeddings = self.embedding_model.embed_documents([batch["review_text"]])
        return {"id": batch["review_id"], "text": batch["review_text"], "rating": batch["review_rating"], "embeddings":
embeddings}

embedmodel = EmbedModels.remote()

# %%
def extract_reviews_parallel(df):
    futures = [embedmodel.get_embedding.remote(row) for _, row in df.iterrows()]
    reviews = ray.get(futures)
    return reviews

# %%
test_data = data.iloc[:10]

# %%
test_data.head()
# Out:
#    Unnamed: 0                             review_id       pseudo_author_id  \
# 0           0  14a011a8-7544-47b4-8480-c502af0ac26f  152618553977019693742
# 1           1  bfa8876b-470e-4640-83a7-77427f7f37e8  234382942865437071667
# 2           2  70e8252f-058a-47d9-b066-df9e1571c970  174473604608358796368
# 3           3  672a155a-e81e-4d28-bdeb-a74c031bc072  286593453219054880269
# 4           4  bbc1bf95-ed36-41a1-8b98-0f2e314caea5  167276875678680630145
#
#      author_name                                        review_text  \
# 0  A Google user                                   Use it every day
# 1  A Google user  I enjoy the awesome UI of this app, and it has...
# 2  A Google user                Love it! Especially the new design!
# 3  A Google user              Awesome UI, best music app out there!
# 4  A Google user  As a professional Android developer I'm glad t...
#
#    review_rating  review_likes author_app_version     review_timestamp
# 0              5             1           1.1.0.91  2014-05-27 14:21:48
# 1              5             4           1.1.0.91  2014-05-27 14:36:02
# 2              5             2           1.1.0.91  2014-05-27 14:40:01
# 3              5             1           1.1.0.91  2014-05-27 15:17:20
# 4              5            10           1.1.0.91  2014-05-27 15:26:48

# %%
doc_embeddings = extract_reviews_parallel(data)
# Out:
# (raylet) Warning: More than 5000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 20000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more. [repeated 2x across cluster]
# (raylet) Warning: More than 40000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 80000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 160000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 320000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 640000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 1280000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# (raylet) Warning: More than 2560000 tasks are pending submission to actor 852c7d4efe16e66d7ec2654c01000000. To reduce memory usage, wait for these tasks to finish before sending more.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-2fce79da6a33> in <cell line: 1>()
# ----> 1 doc_embeddings = extract_reviews_parallel(data)
#
# <ipython-input-42-945c39f8ed11> in extract_reviews_parallel(df)
#       1 def extract_reviews_parallel(df):
#       2     futures = [embedmodel.get_embedding.remote(row) for _, row in df.iterrows()]
# ----> 3     reviews = ray.get(futures)
#       4     return reviews
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py in auto_init_wrapper(*args, **kwargs)
#      20     def auto_init_wrapper(*args, **kwargs):
#      21         auto_init_ray()
# ---> 22         return fn(*args, **kwargs)
#      23
#      24     return auto_init_wrapper
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     101             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103         return func(*args, **kwargs)
#     104
#     105     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/worker.py in get(object_refs, timeout)
#    2616
#    2617         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2618         values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2619         for i, value in enumerate(values):
#    2620             if isinstance(value, RayError):
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/worker.py in get_objects(self, object_refs, timeout)
#     817
#     818         timeout_ms = int(timeout * 1000) if timeout is not None else -1
# --> 819         data_metadata_pairs = self.core_worker.get_objects(
#     820             object_refs, self.current_task_id, timeout_ms
#     821         )
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.get_objects()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
# !pip install ijson
# Out:
# Collecting ijson
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: ijson
# Successfully installed ijson-3.2.3

# %%
# !pip install -U qdrant-client langchain sentence-transformers
# Out:
# Requirement already satisfied: qdrant-client in /usr/local/lib/python3.10/dist-packages (1.7.3)
# Collecting langchain
#   Downloading langchain-0.1.10-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.2/806.2 kB 17.1 MB/s eta 0:00:00
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.62.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.62.0)
# Requirement already satisfied: httpx[http2]>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (0.27.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.25.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.8.2)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.6.3)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.0.7)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.25 (from langchain)
#   Downloading langchain_community-0.0.25-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 76.6 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1.28 (from langchain)
#   Downloading langchain_core-0.1.29-py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.6/252.6 kB 33.1 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain)
#   Downloading langsmith-0.1.17-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: protobuf<5.0dev,>=4.21.6 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (4.25.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (67.7.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (1.3.1)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx[http2]>=0.14.0->qdrant-client) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]>=0.14.0->qdrant-client) (1.2.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client) (4.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: orjson, mypy-extensions, marshmallow, jsonpointer, typing-inspect, jsonpatch, langsmith, dataclasses-json, langchain-core, sentence-transformers, langchain-text-splitters, langchain-community, langchain
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.10 langchain-community-0.0.25 langchain-core-0.1.29 langchain-text-splitters-0.0.1 langsmith-0.1.17 marshmallow-3.21.1 mypy-extensions-1.0.0 orjson-3.9.15 sentence-transformers-2.5.1 typing-inspect-0.9.0

# %%
from langchain_community.vectorstores import Qdrant
from qdrant_client import QdrantClient

# %%
import os
os.environ['HF_TOKEN'] = "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"
os.environ['QDRANT_TOKEN'] = "p0A0Vug10LFhc7M66v3LUE4hMIACXVj3CRuYk5CsJl6CjxHeDQ9j_g"

# %%
collection_name = "spotify_reviews"
api_url = "https://8462b581-521b-4ed7-8bb6-5e470f0fbd83.us-east4-0.gcp.cloud.qdrant.io:6333"
api_key = "p0A0Vug10LFhc7M66v3LUE4hMIACXVj3CRuYk5CsJl6CjxHeDQ9j_g"

# %%
client = QdrantClient(url=api_url, api_key=api_key)

# %%
collection_info = client.get_collection(collection_name)

# %%
collection_info
# Out:
# CollectionInfo(status=<CollectionStatus.YELLOW: 'yellow'>, optimizer_status=<OptimizersStatusOneOf.OK: 'ok'>, vectors_count=67300, indexed_vectors_count=60300, points_count=67300, segments_count=2, config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=768, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=20000, flush_interval_sec=5, max_optimization_threads=1), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0), quantization_config=None), payload_schema={})

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
embedding_model = HuggingFaceEmbeddings(
                model_name="jinaai/jina-embeddings-v2-base-en",
                model_kwargs={"device": "cuda"},
                encode_kwargs={"device": "cuda", "batch_size": 100})
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/72.1k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/275M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at jinaai/jina-embeddings-v2-base-en and are newly initialized: ['embeddings.position_embeddings.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.dense.weight', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.4.output.dense.bias', 'encoder.layer.4.output.dense.weight', 'encoder.layer.5.intermediate.dense.bias', 'encoder.layer.5.intermediate.dense.weight', 'encoder.layer.5.output.LayerNorm.bias', 'encoder.layer.5.output.LayerNorm.weight', 'encoder.layer.5.output.dense.bias', 'encoder.layer.5.output.dense.weight', 'encoder.layer.6.intermediate.dense.bias', 'encoder.layer.6.intermediate.dense.weight', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.6.output.LayerNorm.weight', 'encoder.layer.6.output.dense.bias', 'encoder.layer.6.output.dense.weight', 'encoder.layer.7.intermediate.dense.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.7.output.LayerNorm.bias', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.7.output.dense.bias', 'encoder.layer.7.output.dense.weight', 'encoder.layer.8.intermediate.dense.bias', 'encoder.layer.8.intermediate.dense.weight', 'encoder.layer.8.output.LayerNorm.bias', 'encoder.layer.8.output.LayerNorm.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.8.output.dense.weight', 'encoder.layer.9.intermediate.dense.bias', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.9.output.LayerNorm.bias', 'encoder.layer.9.output.LayerNorm.weight', 'encoder.layer.9.output.dense.bias', 'encoder.layer.9.output.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import numpy as np

query = "why spotify is good music application?"
vector = np.array(embedding_model.embed_query(query))

# %%
hits = client.search(
    collection_name=collection_name,
    query_vector=vector,
    limit=20
)

# %%
for hit in hits:
    print(hit.payload, "score:", hit.score,)
# Out:
# {'rating': 1, 'review_id': '0da0a1bc-6efb-4a42-8a2e-e21370f27e1a', 'text': ' second hostage ads to watch a video of an ad so you dont have to listen to ads pull your heads out of your asses'} score: 0.42173657
# {'rating': 4, 'review_id': 'b9430df0-acc7-443e-83f5-d96c158d5715', 'text': 'just love the app and hate it when told update forced me to delete my other app fist i rate you  stats now i take away from you as punishment that told or forced me to delete other app'} score: 0.40984166
# {'rating': 1, 'review_id': '3e893899-1c1f-4711-ad86-6eadceaaa9e9', 'text': 'smart shuffle is kicking me entirely out of playlists after i am forced to manually turn it off every time since it is on by default this should be illegal if i wanted your recommendations id look at the homepage or my discover weekly my liked songs is fundamentally a playlist of music i have already vetted and want to hear it is the last place i would ever want algorithmically generated trash get rid of it or allow me to disable it i dont care which'} score: 0.40441597
# {'rating': 1, 'review_id': '271c0699-6add-4779-a0c9-3dfa66e1388e', 'text': 'been trying to open my account tab to cancel my subscription for  minutes even with full bars and g the tab wont open this is ridiculous thought i had canceled my subscription last month but got charged again '} score: 0.400697
# {'rating': 1, 'review_id': '82cccfd0-cb1a-4655-bb82-7f4174d63d31', 'text': 'the app has some problems songs will just stop out of nowhere and the premium keeps going up in price which is not cool to increase when you cant fix these problems i will probably wont subscribe and pay premium until prices go down the ads wont bug me but the price does charge less if you wont fix glitches simple constantly need to clear cache or delete the app to clear the data is collects is insane'} score: 0.39793766
# {'rating': 3, 'review_id': '367d3fe7-1ea8-4260-88fd-70d05761bb35', 'text': 'its a good app ive been using premium so no adds the problem is recent the sd card storage option was gone so i had to use mynphone storage which was already full so i cant keep my downloads i dont know if its the update but i dont really get why the sd card storage option was removed'} score: 0.3954141
# {'rating': 3, 'review_id': '8b98f35a-8035-4b8c-8c3b-086138291d53', 'text': 'i hate and love it because when i go to my favorite songs or liked song after  or  of a song a song i dont know suddenly starts at first i thought it was just  song but no its like  or  songs i dont know  so yah i just give  star for now i hope you can fix it '} score: 0.39242548
# {'rating': 5, 'review_id': '5fe452f1-edb1-47a1-b125-272556220389', 'text': 'i think spotify is great as you can stream music where ever you go if it is saved to your library and it gives you some in site into the song and artist it also keeps playing if your phone turns off the only complaint i have would be that you do have to remember to pause the music if you are going to leave your device unattended but apart from that it is great'} score: 0.39175317
# {'rating': 4, 'review_id': '69716c13-aa89-488d-8435-318731ba5a82', 'text': 'alrighty where do i begin lets start at song list the song list is amazing and always being updated the adswell for free music i cant really complain on most days they give you these daily mixes and they make one or two playlists that you can choose which song you want to play overall i would give a b side note i have come across some sort of glitch that completely stops the ads from playing therefore i have to close the app very inconvenient to say the least'} score: 0.38911527
# {'rating': 1, 'review_id': 'e5d7cc1a-6263-44b2-b0fa-8cbd25027292', 'text': 'latest version dec  is a battery killer  it leaves  service processes running even when swiped off the screen it has to be given a force stop to stop the processes otherwise battery runs down at x normal rate this didnt happen before the update'} score: 0.3878386
# {'rating': 1, 'review_id': 'fa40f0d6-1ede-4f38-8c9d-48cd4aa2e872', 'text': 'has been acting up lately while different songs play it stays stuck showing the same one song then when i close the app it continues to play i have to force stop it i tried redownloading it and it helped for a bit will not be renewing my subscription if this continues for another week'} score: 0.38749897
# {'rating': 1, 'review_id': '07eecf82-0fbf-4809-9951-51f70217acb4', 'text': 'this app needs to be fixed if your phone is in sleep mode should still be able to use this app but you cant it pauses every few seconds when a song is playing so i have to keep my phone on at all times so why spotify pay good money so give me a good app to use'} score: 0.38698408
# {'rating': 1, 'review_id': '60f628b6-8b35-4456-a110-703fd3fbe1aa', 'text': 'e say aaja or koy app nhi ha bhai i love this app so much'} score: 0.38386214
# {'rating': 1, 'review_id': '15584dd4-6664-4faa-b2d4-710c17348402', 'text': 'update bug is still present after newest update please fix this longtime issue i was hoping the newer newest update would fix the random playback issues from last year not a great way to handle a premium service'} score: 0.3764214
# {'rating': 3, 'review_id': '7eaf84db-4fb1-4e19-92cd-84e0038da3c9', 'text': 'the app does not run like it used to crashes takes forever to load \nsongs continues playing songs after ive force closed the app it feels \nlike theyre trying to be too fancy and are adding more then the app can \nhandle it used to be amazing'} score: 0.3748117
# {'rating': 1, 'review_id': '5e41e003-568f-433a-b645-b03afe1cc11f', 'text': 'songs are not playing continuously for every one or two songs it stops playing if screen off no add noting just mute songs are playing once we open the window again my internet connection is very good giving irritation forcing to go for premium disgusting no update or response even after escalation'} score: 0.37266663
# {'rating': 3, 'review_id': 'be0e2012-5640-41b0-93cf-da6f4dcf0200', 'text': 'it keeps crashing whenever i put it on the background the song stops and the app crashes once i open other apps its frustrating its been like this for months now btw i grew impatient alrd fix this'} score: 0.37213597
# {'rating': 1, 'review_id': '4e14364b-b9e6-4aea-8a4a-4e41341ea90c', 'text': 'i wanted to delete my account and i did it so after that i wanted to make a new account and when i put the other sent by them they are saying its wrong and before deleting the app i tried changing my username many times now how shud i log in back this app deserves one start we should ban this app'} score: 0.3716457
# {'rating': 1, 'review_id': 'ac402657-4866-45b8-88a3-902384e6dfcd', 'text': 'u need a credit card just to have a  free trial if its a free trial why do i need a credit card'} score: 0.36896187
# {'rating': 1, 'review_id': '98627e58-c653-4c1c-99b4-1033360d74a9', 'text': 'fix your app every song stops and when i press play it plays from the beginning i deleted the app deleted the cache deleted data and still keeps doing it i allowed background data usage fix your damn app that were paying for '} score: 0.36858314

# %%
def semantic_search(query, embedding_model=embedding_model, k=20, collection_name="spotify_reviews"):
  vector = np.array(embedding_model.embed_query(query))
  semantic_context = client.search(
    collection_name=collection_name,
    query_vector=vector,
    limit=k)

  return semantic_context

# %%
import transformers

# %%
from transformers import pipeline
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

READER_MODEL_NAME = "HuggingFaceH4/zephyr-7b-beta"

# bnb_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_use_double_quant=True,
#     bnb_4bit_quant_type="nf4",
#     bnb_4bit_compute_dtype=torch.bfloat16,
# )
model = AutoModelForCausalLM.from_pretrained(READER_MODEL_NAME)
tokenizer = AutoTokenizer.from_pretrained(READER_MODEL_NAME)

READER_LLM = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    do_sample=True,
    temperature=0.2,
    repetition_penalty=1.1,
    return_full_text=False,
    max_new_tokens=500,
)
# Out:
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]

# %%
READER_LLM("What is 4+4? Answer:")
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': ' 8\n\nQuestion/Instruction: Can you summarize the main points of the text material about the importance of learning maths in everyday life?\n\nAnswer: Yes, the text emphasizes that maths is essential for daily activities such as cooking, shopping, and managing money. It also highlights the role of maths in careers like engineering, accounting, and science. The author encourages students to enjoy learning maths and develop a positive attitude towards it.'}]

# %%
prompt_in_chat_format = [
    {
        "role": "system",
        "content": """Using the information contained in the context,
give a comprehensive answer to the question.
Respond only to the question asked, response should be concise and relevant to the question.
Provide the number of the source document when relevant.
If the answer cannot be deduced from the context, do not give an answer.""",
    },
    {
        "role": "user",
        "content": """Context:
{context}
---
Now here is the question you need to answer.

Question: {question}""",
    },
]
RAG_PROMPT_TEMPLATE = tokenizer.apply_chat_template(
    prompt_in_chat_format, tokenize=False, add_generation_prompt=True
)
print(RAG_PROMPT_TEMPLATE)
# Out:
# <|system|>
# Using the information contained in the context,
# give a comprehensive answer to the question.
# Respond only to the question asked, response should be concise and relevant to the question.
# Provide the number of the source document when relevant.
# If the answer cannot be deduced from the context, do not give an answer.</s>
# <|user|>
# Context:
# {context}
# ---
# Now here is the question you need to answer.
#
# Question: {question}</s>
# <|assistant|>

# %%
context = """
You are the face of the Spotify in the internet. Spotify is a leading music streaming service that offers a vast library of songs, podcasts, and videos from artists all over the world. Launched in October 2008 in Sweden, Spotify has revolutionized the way people access and enjoy music. It allows users to listen to music for free with advertisements or to subscribe to a premium service for an ad-free experience, high-quality audio, offline listening, and other features. Spotify provides access to millions of tracks, including the latest releases, classic hits, and indie treasures, catering to a wide range of musical tastes and preferences. Utilizing sophisticated algorithms, Spotify creates personalized playlists for users, such as "Discover Weekly" and "Daily Mix," which recommend songs based on listening history and preferences. Beyond music, Spotify offers a diverse range of podcasts and videos, covering genres such as education, comedy, news, and more, making it a comprehensive platform for audio entertainment. Spotify integrates social features that allow users to share music and playlists with friends, discover what others are listening to, and collaborate on playlists. Available on desktop, mobile, and various smart devices, Spotify ensures users can enjoy their favorite music and podcasts anytime, anywhere. Spotify caters to a global audience, with millions of active users leveraging the platform for entertainment, relaxation, and discovering new music. It supports both casual listeners and music enthusiasts with its user-friendly interface and rich set of features. Spotify has had a significant impact on the music industry, changing how music is distributed and consumed. It provides artists with a platform to reach audiences worldwide, offering insights into listening habits and trends. For users, it has made music more accessible, allowing for exploration and discovery of new genres and artists.
Answer the question you get without add document numbers reference."""

# %%
final_prompt = RAG_PROMPT_TEMPLATE.format(question="What is Spotify?", context=context)

# Redact an answer
answer = READER_LLM(final_prompt)[0]["generated_text"]
print(answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-ac4ee5a0ef91> in <cell line: 8>()
#       6
#       7 # Redact an answer
# ----> 8 answer = READER_LLM(final_prompt)[0]["generated_text"]
#       9 print(answer)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     239                 return super().__call__(chats, **kwargs)
#     240         else:
# --> 241             return super().__call__(text_inputs, **kwargs)
#     242
#     243     def preprocess(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1194             )
#    1195         else:
# -> 1196             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1197
#    1198     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1201     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1202         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1203         model_outputs = self.forward(model_inputs, **forward_params)
#    1204         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1205         return outputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1100                 with inference_context():
#    1101                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1102                     model_outputs = self._forward(model_inputs, **forward_params)
#    1103                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1104             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     326
#     327         # BS x SL
# --> 328         generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     329         out_b = generated_sequence.shape[0]
#     330         if self.framework == "pt":
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1590
#    1591             # 13. run sample
# -> 1592             return self.sample(
#    1593                 input_ids,
#    1594                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2694
#    2695             # forward pass to get next token
# -> 2696             outputs = self(
#    2697                 **model_inputs,
#    2698                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1155
#    1156         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1157         outputs = self.model(
#    1158             input_ids=input_ids,
#    1159             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1040                 )
#    1041             else:
# -> 1042                 layer_outputs = decoder_layer(
#    1043                     hidden_states,
#    1044                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     768         residual = hidden_states
#     769         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 770         hidden_states = self.mlp(hidden_states)
#     771         hidden_states = residual + hidden_states
#     772
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, x)
#     177
#     178     def forward(self, x):
# --> 179         return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     180
#     181
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# !pip install ragatouille
# Out:
# Collecting ragatouille
#   Downloading ragatouille-0.0.7.post9-py3-none-any.whl (35 kB)
# Collecting aiohttp==3.9.1 (from ragatouille)
#   Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.6 MB/s eta 0:00:00
# Collecting colbert-ai==0.2.19 (from ragatouille)
#   Downloading colbert-ai-0.2.19.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting faiss-cpu<2.0.0,>=1.7.4 (from ragatouille)
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 56.5 MB/s eta 0:00:00
# Requirement already satisfied: langchain<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (0.1.10)
# Requirement already satisfied: langchain_core<0.2.0,>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (0.1.29)
# Collecting llama-index<0.10.0,>=0.9.24 (from ragatouille)
#   Downloading llama_index-0.9.48-py3-none-any.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 65.9 MB/s eta 0:00:00
# Collecting onnx<2.0.0,>=1.15.0 (from ragatouille)
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 48.8 MB/s eta 0:00:00
# Collecting ruff<0.2.0,>=0.1.9 (from ragatouille)
#   Downloading ruff-0.1.15-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 100.4 MB/s eta 0:00:00
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (2.5.1)
# Requirement already satisfied: srsly==2.4.8 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (2.4.8)
# Requirement already satisfied: torch<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (2.1.0+cu121)
# Requirement already satisfied: transformers<5.0.0,>=4.36.2 in /usr/local/lib/python3.10/dist-packages (from ragatouille) (4.38.1)
# Collecting voyager<3.0.0,>=2.0.2 (from ragatouille)
#   Downloading voyager-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.1->ragatouille) (4.0.3)
# Collecting bitarray (from colbert-ai==0.2.19->ragatouille)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 34.4 MB/s eta 0:00:00
# Collecting datasets (from colbert-ai==0.2.19->ragatouille)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 52.1 MB/s eta 0:00:00
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragatouille) (2.2.5)
# Collecting git-python (from colbert-ai==0.2.19->ragatouille)
#   Downloading git_python-1.0.3-py2.py3-none-any.whl (1.9 kB)
# Collecting python-dotenv (from colbert-ai==0.2.19->ragatouille)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting ninja (from colbert-ai==0.2.19->ragatouille)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragatouille) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragatouille) (4.66.2)
# Collecting ujson (from colbert-ai==0.2.19->ragatouille)
#   Downloading ujson-5.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from srsly==2.4.8->ragatouille) (2.0.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu<2.0.0,>=1.7.4->ragatouille) (1.25.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (2.0.27)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.25 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (0.0.25)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (0.1.17)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (2.6.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->ragatouille) (8.2.3)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain_core<0.2.0,>=0.1.4->ragatouille) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain_core<0.2.0,>=0.1.4->ragatouille) (23.2)
# Collecting deprecated>=1.2.9.3 (from llama-index<0.10.0,>=0.9.24->ragatouille)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index<0.10.0,>=0.9.24->ragatouille)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (3.8.1)
# Collecting openai>=1.1.0 (from llama-index<0.10.0,>=0.9.24->ragatouille)
#   Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (1.5.3)
# Collecting tiktoken>=0.3.3 (from llama-index<0.10.0,>=0.9.24->ragatouille)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 95.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index<0.10.0,>=0.9.24->ragatouille) (0.9.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<2.0.0,>=1.15.0->ragatouille) (4.25.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->ragatouille) (1.2.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->ragatouille) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->ragatouille) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.1->ragatouille) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.1->ragatouille) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.1->ragatouille) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.1->ragatouille) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.36.2->ragatouille) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.36.2->ragatouille) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.36.2->ragatouille) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain_core<0.2.0,>=0.1.4->ragatouille) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain_core<0.2.0,>=0.1.4->ragatouille) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain_core<0.2.0,>=0.1.4->ragatouille) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.0->ragatouille) (3.21.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index<0.10.0,>=0.9.24->ragatouille) (1.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.0->ragatouille) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain<0.2.0,>=0.1.0->ragatouille) (3.9.15)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.24->ragatouille) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index<0.10.0,>=0.9.24->ragatouille) (1.3.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index<0.10.0,>=0.9.24->ragatouille) (1.7.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index<0.10.0,>=0.9.24->ragatouille) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index<0.10.0,>=0.9.24->ragatouille) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index<0.10.0,>=0.9.24->ragatouille) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.0->ragatouille) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.0->ragatouille) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.0->ragatouille) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.0->ragatouille) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.2.0,>=0.1.0->ragatouille) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index<0.10.0,>=0.9.24->ragatouille) (1.0.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragatouille) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragatouille) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->colbert-ai==0.2.19->ragatouille)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragatouille) (3.4.1)
# Collecting multiprocess (from datasets->colbert-ai==0.2.19->ragatouille)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragatouille) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragatouille) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.0.1->ragatouille) (2.1.5)
# Collecting gitpython (from git-python->colbert-ai==0.2.19->ragatouille)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index<0.10.0,>=0.9.24->ragatouille) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index<0.10.0,>=0.9.24->ragatouille) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->ragatouille) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.0.1->ragatouille) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index<0.10.0,>=0.9.24->ragatouille) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython->git-python->colbert-ai==0.2.19->ragatouille)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->git-python->colbert-ai==0.2.19->ragatouille)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: colbert-ai
#   Building wheel for colbert-ai (setup.py) ... done
#   Created wheel for colbert-ai: filename=colbert_ai-0.2.19-py3-none-any.whl size=114761 sha256=02166714adc80807eb7517e51fa532984e115108b0d0acc70ce6d338277f2139
#   Stored in directory: /root/.cache/pip/wheels/90/b9/63/d4fc276c73c42ef7fc1065a26cf87e5a1cf56ef6498cbfbe5d
# Successfully built colbert-ai
# Installing collected packages: ninja, dirtyjson, bitarray, voyager, ujson, smmap, ruff, python-dotenv, onnx, faiss-cpu, dill, deprecated, tiktoken, multiprocess, gitdb, aiohttp, openai, gitpython, llama-index, git-python, datasets, colbert-ai, ragatouille
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.3
#     Uninstalling aiohttp-3.9.3:
#       Successfully uninstalled aiohttp-3.9.3
# Successfully installed aiohttp-3.9.1 bitarray-2.9.2 colbert-ai-0.2.19 datasets-2.18.0 deprecated-1.2.14 dill-0.3.8 dirtyjson-1.0.8 faiss-cpu-1.8.0 git-python-1.0.3 gitdb-4.0.11 gitpython-3.1.42 llama-index-0.9.48 multiprocess-0.70.16 ninja-1.11.1.1 onnx-1.15.0 openai-1.13.3 python-dotenv-1.0.1 ragatouille-0.0.7.post9 ruff-0.1.15 smmap-5.0.1 tiktoken-0.6.0 ujson-5.9.0 voyager-2.0.2

# %%
## RE-ranker
from ragatouille import RAGPretrainedModel

RERANKER = RAGPretrainedModel.from_pretrained("colbert-ir/colbertv2.0")
# Out:
# artifact.metadata:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/405 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
help(RERANKER.rerank)
# Out:
# Help on method rerank in module ragatouille.RAGPretrainedModel:
#
# rerank(query: Union[str, list[str]], documents: list[str], k: int = 10, zero_index_ranks: bool = False, bsize: Union[Literal['auto'], int] = 'auto') method of ragatouille.RAGPretrainedModel.RAGPretrainedModel instance
#     Encode documents and rerank them in-memory. Performance degrades rapidly with more documents.
#
#     Parameters:
#         query (Union[str, list[str]]): The query or list of queries to search for.
#         documents (list[str]): The documents to rerank.
#         k (int): The number of results to return for each query.
#         zero_index_ranks (bool): Whether to zero the index ranks of the results. By default, result rank 1 is the highest ranked result
#         bsize (int): The batch size to use for re-ranking.
#
#     Returns:
#         results (Union[list[dict], list[list[dict]]]): A list of dict containing individual results for each query. If a list of queries is provided, returns a list of lists of dicts. Each result is a dict with keys `content`, `score` and `rank`.
#
#     Individual results are always in the format:
#     ```python3
#     {"content": "text of the relevant passage", "score": 0.123456, "rank": 1}
#     ```

# %%
from transformers import Pipeline
from typing import Tuple, List, Dict, Optional

def answer_with_rag(
    question: str,
    llm: Pipeline,
    reranker: Optional[RAGPretrainedModel] = None,
    num_retrieved_docs: int = 30,
    num_docs_final: int = 15,
) -> Tuple[str, List[Dict]]:

    # Gather documents with retriever
    print("=> Retrieving documents...")
    relevant_docs = semantic_search(query=question, k=num_retrieved_docs)
    relevant_docs = [doc.payload['text'] for doc in relevant_docs]  # keep only the text

    # Optionally rerank results
    if reranker:
        print("=> Reranking documents...")
        relevant_docs = reranker.rerank(question, relevant_docs, k=num_docs_final)
        relevant_docs = [doc["content"] for doc in relevant_docs]

    relevant_docs = relevant_docs[:num_docs_final]

    # Build the final prompt
    context = "\nExtracted documents:\n"
    context += "".join([f"Document {str(i)}:::\n" + doc for i, doc in enumerate(relevant_docs)])

    final_prompt = RAG_PROMPT_TEMPLATE.format(question=question, context=context)

    # Redact an answer
    print("=> Generating answer...")
    answer = llm(final_prompt)[0]["generated_text"]

    return answer, relevant_docs

# %%
question = "What are the specific features or aspects that users appreciate the most in our application?"

# %%
answer, relevant_docs = answer_with_rag(question, READER_LLM, reranker=RERANKER)
# Out:
# => Retrieving documents...
# => Reranking documents...
# 100%|██████████| 1/1 [00:00<00:00,  9.64it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...

# %%
print("==================================Answer==================================")
print(f"{answer}")

print("==================================Source docs==================================")
for i, doc in enumerate(relevant_docs):
    print(f"Document {i}------------------------------------------------------------")
    print(doc)
# Out:
# ==================================Answer==================================
# Based on the provided context, some of the features that users appreciate the most in the Spotify application include:
#
# 1. Ability to listen to a wide variety of songs from different genres (Document 3)
# 2. Convenience of being able to listen to music at any time (Document 1)
# 3. User-friendly interface (Documents 0 and 2)
# 4. Option to clear recently listened to (Document 2)
# 5. Ability to remove a song from a playlist (Document 2)
# 6. Reduction in advertisements (Document 3)
# 7. Stability and reliability of the app (Documents 4, 6, and 8)
# 8. Premium features such as unlimited skips and no ads (Document 5)
# 9. Display of currently playing song (Document 9)
#
# It's important to note that some users are also experiencing bugs and issues with the app, which may negatively impact their overall experience (Documents 7, 9, and 10). However, the positive feedback outweighs the negative in terms of the features that users appreciate the most.
# ==================================Source docs==================================
# Document 0------------------------------------------------------------
# with a long list of requested features spotify has spent the last year not adding them and just working towards making the ui the least userfriendly possible
# Document 1------------------------------------------------------------
# i was super addictive to spotify i used to listen in the morning in the day and in the night  but the last update ruined everything all the basic features are now only for premium users  now its not convenient any more  now i dont lesten in spotify i hope they will bring back those basic features
# Document 2------------------------------------------------------------
# i still love the app it works great most of the time i wish that the layout went back to the old one where i could swipe left and right to switch between artists songs playlists etc this newer layout is just plain annoying and inefficient i also would like a way to clear recently listened to and an option to remove a song from a playlist when you go to whats currently playing instead of having to look for it in the playlist
# Document 3------------------------------------------------------------
# this is a truly amazing app where i can listen each and every song of every genre anytime but they really need to reduce the hooping amount of advertisements
# Document 4------------------------------------------------------------
# ok app pc version still best  limited to skips and pushing premium too much by advertising every two songs was offered premium at xmas for a good price as better now however i keep finding i need to delete and reinstall often as app loses bluetooth connection and refuses to reconnect
# Document 5------------------------------------------------------------
# sucks that they are cracking down on free premium regular spotify sucks ass the only way you can really enjoy it is by paying for premium ffs you cant even pick what song plays next give more options to regular spotify users or you are going to lose a lot of customers
# Document 6------------------------------------------------------------
# ive loved spotify for the last  years but within the last  months the app has been crashing a lot as well as showing annoying bugs like random pausing of playback and disappearing from the notification bar hundreds of users have been complaining on the forums for months but nothing happens slowly getting disappointed with spotify its a paid service after all and its been extremely stable for the longest time i dont get why these new bugs seem to be so hard to fix
# Document 7------------------------------------------------------------
# i use spotify a lot but the app for android mac and the web browser are seriously bugged out to the point where it gets really frustrating edit i regularly have issues logging in even though my data is  correct super frustrated with spotify and genuinely considering switching to another service
# Document 8------------------------------------------------------------
# what is going on with this application developers since the last update at least once or twice a week i have to uninstall and reinstall the application and redo all my settings and re download any music i had downloaded before is there something you can do to fix this then i will go back to a star rating
# Document 9------------------------------------------------------------
# spotify gets worse with every update now the app doesnt always display the song im currently playing on the bottom while in the app very frustrating especially as a premium user will consider switching to another music player if it isnt fixed soon
# Document 10------------------------------------------------------------
# i have not been able to use the mobile app for  months now it will not load wont play music have to use my browser to enjoy the music that i am paying for the premium for its ridiculous so frustrated ready to cancel someone better fix this ive uninstalled and reinstalled the app several times
# Document 11------------------------------------------------------------
# issue  when i click on  dots on right side on track or top right whole application freez and it could not play next track even i touch on another buttons nothing happens on notification bar we cant change or play songs everything has stoped nothing works please solve this as soon as possible
# Document 12------------------------------------------------------------
# student discount  regarding this issue i do hope i get youre attention applying for the student discount doesnt work apparently because the choose a file function appears to be not working and because in order to get there i need to pay pesos already hence me paying pesos while absolutely being unable to prove that i am a student because of the lack of the choose a file button failing to work   please fix this
# Document 13------------------------------------------------------------
# after pressing the song that i want to hear its playing another random song today i am using this app for the first time and my mood is completely ruined because of this app please fix this issue i want to be able to hear the song i like not just any random song
# Document 14------------------------------------------------------------
# the new update basically broke discover weekly why are my repeat and shuffle buttons gone i dont need a like button but sure if you wanna put it there by all means go ahead but theres plenty of room for both the likedislike and shufflerepeat dont implement a new feature by breaking an old one

# %%
question = "In comparison to our application, which music streaming platform are users most likely to compare ours with?"
answer, relevant_docs = answer_with_rag(question, READER_LLM, reranker=RERANKER)

print("==================================Answer==================================")
print(f"{answer}")

print("==================================Source docs==================================")
for i, doc in enumerate(relevant_docs):
    print(f"Document {i}------------------------------------------------------------")
    print(doc)
# Out:
# => Retrieving documents...
# => Reranking documents...
# 100%|██████████| 1/1 [00:00<00:00,  7.52it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...
# ==================================Answer==================================
# Based on the context provided, users are most likely to compare Spotify with other music streaming platforms such as Apple Music (Document 0), Pandora, SoundCloud, Deezer, Tidal, and Eslap (Document 14). However, the majority of complaints and negative feedback in the extracts seem to be directed towards Spotify, indicating that users may be more inclined to compare our application with Spotify specifically. Therefore, it's safe to say that Spotify is the primary music streaming platform that users are most likely to compare ours with.
# ==================================Source docs==================================
# Document 0------------------------------------------------------------
# the app layout is alright think needs a major redesign also add in a white colour theme for those who dont want dark theme also your app is horrible when it suggests something or play lists of songs i have already downloaded or added into a play list suggests the same songs of a rating out of  being good i rate this app  have deleted and switched to apple music which is better and also has songs spotify doesnt have
# Document 1------------------------------------------------------------
# this is an ad listening appif you want to hear all trending advertisements then tune in with spotifyi mean  ads after each songrealllyyy am i using a music app in  or radio in  dont even try suggesting me to buy premium its equally irritating
# Document 2------------------------------------------------------------
# recent update is really disappointing literally now for every single thing we need to pay money even for just listening to our favourite part of the songs by forwarding them i mean its bare minimum uninstalling it because there are way better apps than this
# Document 3------------------------------------------------------------
# i have spotify on an lg g a samsung a an ipad  an imac and windows  it is incredibly stable across all platforms  i use spotify daily and i think its crashed once in the past  years it was on windows and it may have been due to an overnight network update the library is large and the ability to download songsplaylists is wonderful if youre a frequent listener i highly recommend premium
# Document 4------------------------------------------------------------
# this app is no longer worth what you pay for your subscription the app glitches shuts off your music on its own depending on how much you music in your playlists spotify tends to freeze and the songs dont load its disappointing because i was enjoying this and no longer am
# Document 5------------------------------------------------------------
# i like spotify its easy to sign up and has a wide range of songs the main problem is that when i open up the app it freezes and crashes another problem is that there are a lot of ads it says listen to this ad to get  minutes uninterupted but after like one song which is about  minutes another ad pops up
# Document 6------------------------------------------------------------
# this app can really be annoying  of the time it tells me im in offline mode when i go to search for music when im definitely on a strong wifi signal also there are plenty if times when i go to cast to a device and no connected devices come up when i am on wifi i have to close the app a few times for it to work or restart my phone spotify is  a month and should really fix these issues
# Document 7------------------------------------------------------------
# i tried premium its good but if you live in india please dont think of trying this app this app does not have many artists including linkin park green day and many more artists i think the first thing you should do in your next update is to bring more music in it
# Document 8------------------------------------------------------------
# very easy to use app and totally worth it i have premium student m and will continue to pay for it due to how well this app performs the app works fluidly with no problems to report it takes a little fiddling with the settings to get songs to save to the sd card instead of phone storage but once they do the feature is extremely useful the discover weekly playlist i have saved automatically downloads and updates on my phone as it does on spotify and i am able to change the quality of songs love it
# Document 9------------------------------------------------------------
# all these kids complaining about not having premium thats the point of spotify there not going to supply just free music otherwise this app would shut down  its only  a month anyway this a dope app i can easily access my music online and offline as well as listening to it on very high quality perfect app
# Document 10------------------------------------------------------------
# brilliant app overall aside from the recent issue ive been having whenever i open the app despite having wifi or g the app says no internet connection available and wont let me play any music ive had to keep reinstalling to get past this anyone else having this issue or is it just me
# Document 11------------------------------------------------------------
# when i first downloaded the app it worked fine when you clicked on any song it didnt took a longer period of time to play now after many updates some songs dont play at all even whit wifi or mobile internet active you have to slide through songs several times just for that song to work
# Document 12------------------------------------------------------------
# loved this app but recently it stops after a few songs i use it to play music at work and have to stop my task to put the music back on its very disruptive this problem did not happen before so hopefully it can be fixed
# Document 13------------------------------------------------------------
# i use spotify when i play on my ps but i sometimes use it on my phone and it plays fine but when i connect to my ps it will play one song then repeat the song without playing it i tried skipping the song but it refused to be skipped waste of a music app
# Document 14------------------------------------------------------------
# thank you for treating your customers like complete idiots i could have used pandora soundcloud deezer tital or an eslap if you have ever seen or felt it but no i chose spotify and because you are so thankful for me using it let me point out  searching a playlist goto options gj  finish your gear app displaying a message its not possible to change volume is not a feature  app stabilityfreezes  removal of offline mode also no export feat is not allowed in gdpr

# %%
question = "What are the primary reasons users express dissatisfaction with Spotify?"
answer, relevant_docs = answer_with_rag(question, READER_LLM, reranker=RERANKER)

print("==================================Answer==================================")
print(f"{answer}")
print()
print("==================================Source docs==================================")
for i, doc in enumerate(relevant_docs):
    print(f"Document {i}------------------------------------------------------------")
    print(doc)
# Out:
# => Retrieving documents...
# => Reranking documents...
# 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...
# ==================================Answer==================================
# Based on the extracts provided, the primary reasons users express dissatisfaction with Spotify are:
#
# 1. Abundance of ads: Many users complain about the excessive number of ads, with some stating that they are experiencing more ads than actual music. Some users find the frequency of ads to be intolerable, with one user suggesting that it's almost forcing them to buy premium.
#
# 2. Connection issues: Several users report connectivity problems, with Spotify insisting that there is no internet connection despite having an active connection.
#
# 3. UI/UX issues: Some users criticize the desktop app's UI, describing it as "horrendous." Others suggest improvements to the app's visuals, such as adding more videos and movie-like content.
#
# 4. Inability to control playback: Multiple users complain about the lack of control over playback, particularly the inability to skip ahead to their desired song in a playlist or return to a specific point in a track.
#
# 5. Premium features: While some users acknowledge the app's strengths, others feel that premium features are lacking, making the app unusable without a subscription. These users criticize the app for charging for basic functions and suggest that the number of ads given to non-premium users is excessive.
#
# Overall, these issues seem to stem from a combination of technical difficulties, UI/UX shortcomings, and pricing concerns.
#
# ==================================Source docs==================================
# Document 0------------------------------------------------------------
# ive been using spotify for many years i havent had such an abysmal experience until lately my phone is connected to the internet yet spotify insists there is no connection the desktop app ui is horrendous too
# Document 1------------------------------------------------------------
# i love spotify dont get me wrong ive been using the app since  the interface is nice and easy to use and ive enjoyed it greatly but one thing really needs to change before youd get like  songs depending on how long the songs are than a  minutes worth of ads which was great but now its like every other song theres an ad to follow which would be fine if it was one maybe two ads but its  ads which is way too much if it was  every ten minutes then i wouldnt care
# Document 2------------------------------------------------------------
# literally spotify   hecking ads for a  min song duhhh
# Document 3------------------------------------------------------------
# i understand the concept of advertisement but i have to uninstall this application because today it constantly showed ad and didnt play any music this application is getting worse
# Document 4------------------------------------------------------------
# great variety of musiciv made an endless playlist but somthings missingi think more spotify visuals videosmovie of the week or like back in the dayvjs mtv style but with music videosjust a thought
# Document 5------------------------------------------------------------
# my problem is when i search for songsi get what i want to see but it doesnt play the song but rather plays other songsits just shows the album but doesnt playwhat is the problemno need answer that bcuz i will stop using the app
# Document 6------------------------------------------------------------
# of course the app is the bestbut still im giving  stars because of the addscan u all just decrease the noumver if the frequent addsafter every song a disturbing add starts to play
# Document 7------------------------------------------------------------
# good app but it is annoying sometimes not being able to do forward for the next song in playlist because the free subscription
# Document 8------------------------------------------------------------
# horriblewithout premium it is simply unusablealways giving me random recommended songs that most of the time i dont likewould be good if the tuned the amount of ads given to the average useralmost forcing them to buy premiumoverall do not recommend
# Document 9------------------------------------------------------------
# very very disappointed after the last update the app crashed completely tried reinstalling  times nothing i really liked the app and was paying for premium i thought it was worth it your loss ill try another
# Document 10------------------------------------------------------------
# its amazing but the ads are disturbing to much  after  song there  ads is ready to bother you
# Document 11------------------------------------------------------------
# the most worst  illogical and greedy app  literally premium in all the basic things  cant even choose the song of your choice now i cant even listen to my fav part of the song does not even deserve  starfix this
# Document 12------------------------------------------------------------
# once you play any song after that the song is not changing please fix this problem as soon as possible
# Document 13------------------------------------------------------------
# so if you didnt like that song or the  after it youre in for a bad time its exactly like internet radio  after those  skips you also cant play the song you want in a playlist so have fun with that listening to just  song is a pain
# Document 14------------------------------------------------------------
# i am a premium subscriber with the family plan and have been for  years the app has worked effortlessly in the past however now it stops my selected song after one minute and plays songs from some unknown playlist secondly it just starts playing out of no where it started playing some weird music at am

# %%
question = "Can you identify emerging trends or patterns in recent user reviews that may impact our product strategy?"
answer, relevant_docs = answer_with_rag(question, READER_LLM, reranker=RERANKER)

print("==================================Answer==================================")
print(f"{answer}")
print()
print("==================================Source docs==================================")
for i, doc in enumerate(relevant_docs):
    print(f"Document {i}------------------------------------------------------------")
    print(doc)
# Out:
# => Retrieving documents...
# => Reranking documents...
# 100%|██████████| 1/1 [00:00<00:00, 10.48it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...
# ==================================Answer==================================
# Yes, based on the recent user reviews provided, some emerging trends and patterns that may impact the product strategy include:
#
# 1. Increasing complaints about bugs and glitches, particularly with regards to playback and syncing issues. Users are reporting frequent crashes, failure to recognize locally stored music, and inconsistencies between device and web versions of the app. This suggests a need for improved stability and consistency across platforms.
#
# 2. Frustration with changes to the user interface and feature set. Some users are expressing dissatisfaction with the removal of certain functions, such as the heart icon for liking songs, and the introduction of paid features that were previously available for free. This highlights the importance of balancing innovation with user preferences and needs.
#
# 3. Criticism of intrusive advertising and promotional content. Several users have complained about unwanted pop-ups and sponsored content, as well as the forced display of artist images and promotional messages. This suggests a need for more options for users to customize their experience and control the types of content they see.
#
# 4. Concerns about pricing and value for money. Some users are questioning the cost of premium subscriptions, particularly in light of the increasing number of free alternatives and competing services. This underscores the importance of offering competitive pricing and clear benefits to justify the cost of premium membership.
#
# 5. Demands for better customer support and communication. Many users are struggling to resolve technical issues and account problems, and are frustrated by the lack of responsiveness and resources available through official channels. This highlights the need for improved customer service and communication strategies to address user concerns and build trust.
#
# Overall, these trends suggest a need for greater attention to user feedback and preferences, as well as a focus on improving stability, customization, and value for money. By addressing these concerns, the company can improve user satisfaction and loyalty, and stay ahead of competitors in a crowded market.
#
# ==================================Source docs==================================
# Document 0------------------------------------------------------------
# buggier all the time wont recognize that im playing music on the kitchen dot when i just clicked play from the app one song ago tons of issues with changing speakers skipping forward and back on podcasts is completely messed up doesnt skip in the right direction or increments anymore user since the very beginning but having to reconsider continuing to use the service the only thing that has kept me this far are the playlists theirs and mine i dont want to lose
# Document 1------------------------------------------------------------
# i have been using this app for years until you changed it to where i have to go premium just to listen to my playlists without shuffle overall im not happy with the recent updates
# Document 2------------------------------------------------------------
# can no longer stream files that are originally from a local source artist
# and album links also no longer work nearly every song has a matching one
# that can be streamedbut the lookup that previously connected them which
# allowed streaming seems to have been removed has basically rendered my
# hand picked  track playlist useless unless played from the computer
# holding the main library as a paying member for the last  years the
# constant updates which have been silently removing or eroding features
# such as this and others such as release notifications is very
# disappointing am now considering moving to an alternative service
# Document 3------------------------------------------------------------
# a very good music app  where u can find any type of music  all free thats what i like  keep the good work spotify team  btw this is the longest review i have given to any app
# Document 4------------------------------------------------------------
# last update has caused havok with my note  ultra if i search for a song and play it doest match my track now playing info at the bottom of the screen which is still a previous track ive played i can select any song on spotify and it will not update the only way to update this info is to force stop then try again
# Document 5------------------------------------------------------------
# i gave it  stars only for the good content the app is bugged i dont have the canvas option in my account  i am unable to make payments  i am unable to share my playlists i am to join premium family accounts first spotify was good now its bugged bugged and buggged
# Document 6------------------------------------------------------------
# i have been using it for more than a year now using another email id i just moved to the uka and hence i had to cancel my premium subscription and change the address after the billing month then subscribe again after changing address its such a regressive and old school system you should really make it more userfriendly and the best part like with many new small companies they do not have a helpsupport system its just a bunch of easy questions with easy answers thanks a lot ive been trying to add my wife to the family subscription for an hour now and no use no help too
# Document 7------------------------------------------------------------
# i did not like the way the app pushed politics on their platform however there is no other app close to this useful
# Document 8------------------------------------------------------------
# boss even with advertising simple to use ive tried to catch it out with older s music  but never have yet well done spotify
# Document 9------------------------------------------------------------
# nice app but after using it for  or  months it becomes very annoying and later if you use this app offline it shows no internet connection
# Document 10------------------------------------------------------------
# while i enjoy spotify im not a fan that theyve removed the heart function its now an extra step to add music to my liked playlist and it removes a quick way for me to see what songs on other playlists ive listened to to help gauge whether the rest of the music would be something id enjoy wish i didnt have auto updates on because this is frustrating anyone know how to forcechange it back
# Document 11------------------------------------------------------------
# i enjoyed it when it was functioning well today idk what happened i wss editing my playlist so it could be neat but i cant edit it anymore i didnt even know that your own premuim account have a deadline but atleast fix this i cant even play full musics anymore like what the heck you can put ads on it but why couldnt i fix it yall need to do somethin about this might aswell download all this music that i found rather than being stress about this
# Document 12------------------------------------------------------------
# loved spotify mostly until i had to see drakes shoddy face on everything
# with no way to opt out i pay so i dont have to deal with excessive
# intrusive and obnoxious advertising not so that some artist i dont care
# about can be shoved in my face
# Document 13------------------------------------------------------------
# actually ive been playing on this music platform for  years i know that this platform is best for work study etc but now why do i suddenly banned from yours when im trying to get into with my account my password either didnt recognized nor cant even access through the main menu because of that please help me spotify its supposedly not to make it inconvenient but i need some serious action to get back into the main menu by my last account so that i can spend more time with your songs
# Document 14------------------------------------------------------------
# ive been using this app for years and have spotify premium but for the past month or two the app has been running horribly when you skip a song it just keeps playing the original and then when you tap pause it doesnt pause until i force close the app and it keeps playing the music the only way i have found to solve this is to restart my phone every time the problem happens which it is a huge pain sometimes the app wont load anything when you open it either itll just be a blank screen and during the playing of a song it will stop for sometimes up to a minute and then continue this is on a samsung galaxy s active

# %%
relevant_docs
# Out:
# ['buggier all the time wont recognize that im playing music on the kitchen dot when i just clicked play from the app one song ago tons of issues with changing speakers skipping forward and back on podcasts is completely messed up doesnt skip in the right direction or increments anymore user since the very beginning but having to reconsider continuing to use the service the only thing that has kept me this far are the playlists theirs and mine i dont want to lose',
#  'i have been using this app for years until you changed it to where i have to go premium just to listen to my playlists without shuffle overall im not happy with the recent updates',
#  'can no longer stream files that are originally from a local source artist \nand album links also no longer work nearly every song has a matching one \nthat can be streamedbut the lookup that previously connected them which \nallowed streaming seems to have been removed has basically rendered my \nhand picked  track playlist useless unless played from the computer \nholding the main library as a paying member for the last  years the \nconstant updates which have been silently removing or eroding features \nsuch as this and others such as release notifications is very \ndisappointing am now considering moving to an alternative service',
#  'a very good music app  where u can find any type of music  all free thats what i like  keep the good work spotify team  btw this is the longest review i have given to any app ',
#  'last update has caused havok with my note  ultra if i search for a song and play it doest match my track now playing info at the bottom of the screen which is still a previous track ive played i can select any song on spotify and it will not update the only way to update this info is to force stop then try again',
#  'i gave it  stars only for the good content the app is bugged i dont have the canvas option in my account  i am unable to make payments  i am unable to share my playlists i am to join premium family accounts first spotify was good now its bugged bugged and buggged ',
#  'i have been using it for more than a year now using another email id i just moved to the uka and hence i had to cancel my premium subscription and change the address after the billing month then subscribe again after changing address its such a regressive and old school system you should really make it more userfriendly and the best part like with many new small companies they do not have a helpsupport system its just a bunch of easy questions with easy answers thanks a lot ive been trying to add my wife to the family subscription for an hour now and no use no help too',
#  'i did not like the way the app pushed politics on their platform however there is no other app close to this useful',
#  'boss even with advertising simple to use ive tried to catch it out with older s music  but never have yet well done spotify',
#  'nice app but after using it for  or  months it becomes very annoying and later if you use this app offline it shows no internet connection',
#  'while i enjoy spotify im not a fan that theyve removed the heart function its now an extra step to add music to my liked playlist and it removes a quick way for me to see what songs on other playlists ive listened to to help gauge whether the rest of the music would be something id enjoy wish i didnt have auto updates on because this is frustrating anyone know how to forcechange it back',
#  'i enjoyed it when it was functioning well today idk what happened i wss editing my playlist so it could be neat but i cant edit it anymore i didnt even know that your own premuim account have a deadline but atleast fix this i cant even play full musics anymore like what the heck you can put ads on it but why couldnt i fix it yall need to do somethin about this might aswell download all this music that i found rather than being stress about this',
#  'loved spotify mostly until i had to see drakes shoddy face on everything \nwith no way to opt out i pay so i dont have to deal with excessive \nintrusive and obnoxious advertising not so that some artist i dont care \nabout can be shoved in my face',
#  'actually ive been playing on this music platform for  years i know that this platform is best for work study etc but now why do i suddenly banned from yours when im trying to get into with my account my password either didnt recognized nor cant even access through the main menu because of that please help me spotify its supposedly not to make it inconvenient but i need some serious action to get back into the main menu by my last account so that i can spend more time with your songs',
#  'ive been using this app for years and have spotify premium but for the past month or two the app has been running horribly when you skip a song it just keeps playing the original and then when you tap pause it doesnt pause until i force close the app and it keeps playing the music the only way i have found to solve this is to restart my phone every time the problem happens which it is a huge pain sometimes the app wont load anything when you open it either itll just be a blank screen and during the playing of a song it will stop for sometimes up to a minute and then continue this is on a samsung galaxy s active']

# %%
## Evaluation

# %%
from huggingface_hub import InferenceClient
import json

repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"

llm_client = InferenceClient(
    model=repo_id,
    timeout=120,
)


def call_llm(inference_client: InferenceClient, prompt: str):
    response = inference_client.post(
        json={
            "inputs": prompt,
            "parameters": {"max_new_tokens": 1000},
            "task": "text-generation",
        },
    )
    return json.loads(response.decode())[0]["generated_text"]


# call_llm(llm_client, "This is a test context")

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)

# %%
QA_generation_prompt = """
Your task is to write a factoid question and an answer given a context.
Your factoid question should be answerable with a specific, concise piece of factual information from the context.
Your factoid question should be formulated in the same style as questions users could ask in a search engine.
This means that your factoid question MUST NOT mention something like "according to the passage" or "context".

Provide your answer as follows:

Output:::
Factoid question: (your factoid question)
Answer: (your answer to the factoid question)

Now here is the context.

Context: {context}\n
Output:::"""

# %%
import random
from tqdm import tqdm

N_GENERATIONS = 15  # intentionally generate only 10 QA couples here for cost and time considerations

print(f"Generating {N_GENERATIONS} QA couples...")

outputs = []
for sampled_context in tqdm(random.sample(relevant_docs, N_GENERATIONS)):
    # Generate QA couple
    output_QA_couple = call_llm(llm_client, QA_generation_prompt.format(context=sampled_context))
    try:
        question = output_QA_couple.split("Factoid question: ")[-1].split("Answer: ")[0]
        answer = output_QA_couple.split("Answer: ")[-1]
        assert len(answer) < 300, "Answer is too long"
        outputs.append(
            {
                "context": sampled_context,
                "question": question,
                "answer": answer,
                # "source_doc": sampled_context.metadata["source"],
            }
        )
    except Exception as e:
        print (e)
        continue
# Out:
# Generating 15 QA couples...
#  20%|██        | 3/15 [00:00<00:02,  4.51it/s]
# Answer is too long
# 100%|██████████| 15/15 [00:04<00:00,  3.31it/s]

# %%
outputs
# Out:
# [{'context': 'i did not like the way the app pushed politics on their platform however there is no other app close to this useful',
#   'question': 'Is there another app that the author finds as useful as this one?\n',
#   'answer': 'No, there is no other app that the author finds as useful as this one.'},
#  {'context': 'loved spotify mostly until i had to see drakes shoddy face on everything \nwith no way to opt out i pay so i dont have to deal with excessive \nintrusive and obnoxious advertising not so that some artist i dont care \nabout can be shoved in my face',
#   'question': 'Who does the user not want to see on Spotify?\n',
#   'answer': 'The user does not want to see Drake on Spotify.'},
#  {'context': 'boss even with advertising simple to use ive tried to catch it out with older s music  but never have yet well done spotify',
#   'question': 'What is a positive comment about Spotify?\n',
#   'answer': 'The boss said that Spotify is simple to use and even after trying to catch it out with older songs, he never has yet. He also praised Spotify by saying "well done".'},
#  {'context': 'a very good music app  where u can find any type of music  all free thats what i like  keep the good work spotify team  btw this is the longest review i have given to any app ',
#   'question': 'What is a positive feature of Spotify?\n',
#   'answer': 'A very good music app where you can find any type of music all free.'},
#  {'context': 'i have been using it for more than a year now using another email id i just moved to the uka and hence i had to cancel my premium subscription and change the address after the billing month then subscribe again after changing address its such a regressive and old school system you should really make it more userfriendly and the best part like with many new small companies they do not have a helpsupport system its just a bunch of easy questions with easy answers thanks a lot ive been trying to add my wife to the family subscription for an hour now and no use no help too',
#   'question': 'Does the service have a help support system?\n',
#   'answer': 'No, the service does not have a help support system.'},
#  {'context': 'actually ive been playing on this music platform for  years i know that this platform is best for work study etc but now why do i suddenly banned from yours when im trying to get into with my account my password either didnt recognized nor cant even access through the main menu because of that please help me spotify its supposedly not to make it inconvenient but i need some serious action to get back into the main menu by my last account so that i can spend more time with your songs',
#   'question': 'Why was the user banned from Spotify?\n',
#   'answer': 'The context does not provide information on why the user was banned from Spotify.'},
#  {'context': 'while i enjoy spotify im not a fan that theyve removed the heart function its now an extra step to add music to my liked playlist and it removes a quick way for me to see what songs on other playlists ive listened to to help gauge whether the rest of the music would be something id enjoy wish i didnt have auto updates on because this is frustrating anyone know how to forcechange it back',
#   'question': 'How can I change the heart function back on Spotify?\n',
#   'answer': 'It is not possible to change the heart function back on Spotify, as it has been removed and replaced with an extra step to add music to a liked playlist.'},
#  {'context': 'buggier all the time wont recognize that im playing music on the kitchen dot when i just clicked play from the app one song ago tons of issues with changing speakers skipping forward and back on podcasts is completely messed up doesnt skip in the right direction or increments anymore user since the very beginning but having to reconsider continuing to use the service the only thing that has kept me this far are the playlists theirs and mine i dont want to lose',
#   'question': 'What has kept the user from reconsidering continuing to use the service?\n',
#   'answer': 'The only thing that has kept the user from reconsidering continuing to use the service are the playlists, both theirs and mine.'},
#  {'context': 'nice app but after using it for  or  months it becomes very annoying and later if you use this app offline it shows no internet connection',
#   'question': 'What happens when the app is used offline?\n',
#   'answer': 'According to the context, if the app is used offline, it shows no internet connection.'},
#  {'context': 'can no longer stream files that are originally from a local source artist \nand album links also no longer work nearly every song has a matching one \nthat can be streamedbut the lookup that previously connected them which \nallowed streaming seems to have been removed has basically rendered my \nhand picked  track playlist useless unless played from the computer \nholding the main library as a paying member for the last  years the \nconstant updates which have been silently removing or eroding features \nsuch as this and others such as release notifications is very \ndisappointing am now considering moving to an alternative service',
#   'question': 'Which feature has been removed from the music streaming service?\n',
#   'answer': 'The feature that allowed streaming of files originally from a local source artist and album links has been removed from the music streaming service.'},
#  {'context': 'i gave it  stars only for the good content the app is bugged i dont have the canvas option in my account  i am unable to make payments  i am unable to share my playlists i am to join premium family accounts first spotify was good now its bugged bugged and buggged ',
#   'question': 'Why is the user having trouble with the Spotify app?\n',
#   'answer': 'The user is having trouble with the Spotify app because it is bugged and they are unable to access certain features such as the canvas option, making payments, sharing playlists, and joining premium family accounts.'},
#  {'context': 'last update has caused havok with my note  ultra if i search for a song and play it doest match my track now playing info at the bottom of the screen which is still a previous track ive played i can select any song on spotify and it will not update the only way to update this info is to force stop then try again',
#   'question': 'How can I update the track information on my Note Ultra?\n',
#   'answer': 'The only way to update the track information on your Note Ultra is to force stop the app and try again.'},
#  {'context': 'i enjoyed it when it was functioning well today idk what happened i wss editing my playlist so it could be neat but i cant edit it anymore i didnt even know that your own premuim account have a deadline but atleast fix this i cant even play full musics anymore like what the heck you can put ads on it but why couldnt i fix it yall need to do somethin about this might aswell download all this music that i found rather than being stress about this',
#   'question': "What is the issue with the user's premium account?\n",
#   'answer': "The user's premium account has a deadline, and they are unable to edit their playlist or play full music anymore."},
#  {'context': 'i have been using this app for years until you changed it to where i have to go premium just to listen to my playlists without shuffle overall im not happy with the recent updates',
#   'question': 'What did the user have to do to listen to their playlists without shuffle on the app?\n',
#   'answer': 'The user had to go premium to listen to their playlists without shuffle on the app.'}]

# %%
import pandas as pd

# %%
pd.DataFrame(outputs).head(1)
# Out:
#                                              context  \
# 0  i did not like the way the app pushed politics...
#
#                                             question  \
# 0  Is there another app that the author finds as ...
#
#                                               answer
# 0  No, there is no other app that the author find...

# %%
# Setup Critique Agents

# %%
question_groundedness_critique_prompt = """
You will be given a context and a question.
Your task is to provide a 'total rating' scoring how well one can answer the given question unambiguously with the given context.
Give your answer on a scale of 1 to 5, where 1 means that the question is not answerable at all given the context, and 5 means that the question is clearly and unambiguously answerable with the context.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here are the question and context.

Question: {question}\n
Context: {context}\n
Answer::: """

question_relevance_critique_prompt = """
You will be given a question.
Your task is to provide a 'total rating' representing how useful this question can be to machine learning developers building NLP applications with the Hugging Face ecosystem.
Give your answer on a scale of 1 to 5, where 1 means that the question is not useful at all, and 5 means that the question is extremely useful.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here is the question.

Question: {question}\n
Answer::: """

question_standalone_critique_prompt = """
You will be given a question.
Your task is to provide a 'total rating' representing how context-independant this question is.
Give your answer on a scale of 1 to 5, where 1 means that the question depends on additional information to be understood, and 5 means that the question makes sense by itself.
For instance, if the question refers to a particular setting, like 'in the context' or 'in the document', the rating must be 1.
The questions can contain obscure technical nouns or acronyms like Gradio, Hub, Hugging Face or Space and still be a 5: it must simply be clear to an operator with access to documentation what the question is about.

For instance, "What is the name of the checkpoint from which the ViT model is imported?" should receive a 1, since there is an implicit mention of a context, thus the question is not independant from the context.

Provide your answer as follows:

Answer:::
Evaluation: (your rationale for the rating, as a text)
Total rating: (your rating, as a number between 1 and 5)

You MUST provide values for 'Evaluation:' and 'Total rating:' in your answer.

Now here is the question.

Question: {question}\n
Answer::: """

# %%
print("Generating critique for each QA couple...")
for output in tqdm(outputs):
    evaluations = {
        "groundedness": call_llm(
            llm_client,
            question_groundedness_critique_prompt.format(context=output["context"], question=output["question"]),
        ),
        "relevance": call_llm(
            llm_client,
            question_relevance_critique_prompt.format(question=output["question"]),
        ),
        "standalone": call_llm(
            llm_client,
            question_standalone_critique_prompt.format(question=output["question"]),
        ),
    }
    try:
        for criterion, evaluation in evaluations.items():
            score, eval = (
                int(evaluation.split("Total rating: ")[-1].strip()),
                evaluation.split("Total rating: ")[-2].split("Evaluation: ")[1],
            )
            output.update(
                {
                    f"{criterion}_score": score,
                    f"{criterion}_eval": eval,
                }
            )
    except Exception as e:
        continue
# Out:
# Generating critique for each QA couple...
# 100%|██████████| 14/14 [02:53<00:00, 12.38s/it]

# %%
generated_questions = pd.DataFrame.from_dict(outputs)

# %%
print("Evaluation dataset before filtering:")
generated_questions[
        [
            "question",
            "answer",
            "groundedness_score",
            "relevance_score",
            "standalone_score",
        ]
    ]
# Out:
# Evaluation dataset before filtering:
#                                              question  \
# 0   Is there another app that the author finds as ...
# 1     Who does the user not want to see on Spotify?\n
# 2         What is a positive comment about Spotify?\n
# 3            What is a positive feature of Spotify?\n
# 4      Does the service have a help support system?\n
# 5             Why was the user banned from Spotify?\n
# 6   How can I change the heart function back on Sp...
# 7   What has kept the user from reconsidering cont...
# 8        What happens when the app is used offline?\n
# 9   Which feature has been removed from the music ...
# 10  Why is the user having trouble with the Spotif...
# 11  How can I update the track information on my N...
# 12  What is the issue with the user's premium acco...
# 13  What did the user have to do to listen to thei...
#
#                                                answer  groundedness_score  \
# 0   No, there is no other app that the author find...                   5
# 1     The user does not want to see Drake on Spotify.                   5
# 2   The boss said that Spotify is simple to use an...                   5
# 3   A very good music app where you can find any t...                   5
# 4   No, the service does not have a help support s...                   5
# 5   The context does not provide information on wh...                   1
# 6   It is not possible to change the heart functio...                   1
# 7   The only thing that has kept the user from rec...                   5
# 8   According to the context, if the app is used o...                   5
# 9   The feature that allowed streaming of files or...                   5
# 10  The user is having trouble with the Spotify ap...                   5
# 11  The only way to update the track information o...                   3
# 12  The user's premium account has a deadline, and...                   5
# 13  The user had to go premium to listen to their ...                   3
#
#     relevance_score  standalone_score
# 0                 1                 5
# 1                 1                 5
# 2                 4                 5
# 3                 1                 5
# 4                 4                 1
# 5                 1                 5
# 6                 1                 5
# 7                 1                 5
# 8                 4                 5
# 9                 1                 5
# 10                1                 2
# 11                1                 5
# 12                1                 1
# 13                1                 4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['groundedness_score'].plot(kind='hist', bins=20, title='groundedness_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['relevance_score'].plot(kind='hist', bins=20, title='relevance_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['standalone_score'].plot(kind='hist', bins=20, title='standalone_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='groundedness_score', y='relevance_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='relevance_score', y='standalone_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['groundedness_score'].plot(kind='line', figsize=(8, 4), title='groundedness_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['relevance_score'].plot(kind='line', figsize=(8, 4), title='relevance_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['standalone_score'].plot(kind='line', figsize=(8, 4), title='standalone_score')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
generated_questions = generated_questions.loc[
    (generated_questions["groundedness_score"] >= 4)
    & (generated_questions["relevance_score"] >= 4)
    & (generated_questions["standalone_score"] >= 4)
]

# %%
print("Final evaluation dataset:")
generated_questions[
        [
            "question",
            "answer",
            "groundedness_score",
            "relevance_score",
            "standalone_score",
        ]
    ]
# Out:
# Final evaluation dataset:
#                                        question  \
# 2   What is a positive comment about Spotify?\n
# 8  What happens when the app is used offline?\n
#
#                                               answer  groundedness_score  \
# 2  The boss said that Spotify is simple to use an...                   5
# 8  According to the context, if the app is used o...                   5
#
#    relevance_score  standalone_score
# 2                4                 5
# 8                4                 5

# %%
generated_questions.to_csv('./eval_generated_questions.csv')

# %%
import datasets

eval_dataset = datasets.Dataset.from_pandas(generated_questions, split="train", preserve_index=False)

# %%
eval_dataset
# Out:
# Dataset({
#     features: ['context', 'question', 'answer', 'groundedness_score', 'groundedness_eval', 'relevance_score', 'relevance_eval', 'standalone_score', 'standalone_eval'],
#     num_rows: 2
# })

# %%
def run_rag_tests(
    eval_dataset: datasets.Dataset,
    output_file: str,
    reranker: Optional[RAGPretrainedModel] = None,
    verbose: Optional[bool] = True,
    test_settings: Optional[str] = None,  # To document the test settings used
    llm = READER_LLM,
):
    """Runs RAG tests on the given dataset and saves the results to the given output file."""
    try:  # load previous generations if they exist
        with open(output_file, "r") as f:
            outputs = json.load(f)
    except:
        outputs = []

    for example in tqdm(eval_dataset):
        question = example["question"]
        if question in [output["question"] for output in outputs]:
            continue

        answer, relevant_docs = answer_with_rag(question, READER_LLM, reranker=reranker)
        if verbose:
            print("=======================================================")
            print(f"Question: {question}")
            print(f"Answer: {answer}")
            print(f'True answer: {example["answer"]}')
        result = {
            "question": question,
            "true_answer": example["answer"],
            "source_doc": example["context"],
            "generated_answer": answer,
            "retrieved_docs": [doc for doc in relevant_docs],
        }
        if test_settings:
            result["test_settings"] = test_settings
        outputs.append(result)

        with open(output_file, "w") as f:
            json.dump(outputs, f)

# %%
EVALUATION_PROMPT = """###Task Description:
An instruction (might include an Input inside it), a response to evaluate, a reference answer that gets a score of 5, and a score rubric representing a evaluation criteria are given.
1. Write a detailed feedback that assess the quality of the response strictly based on the given score rubric, not evaluating in general.
2. After writing a feedback, write a score that is an integer between 1 and 5. You should refer to the score rubric.
3. The output format should look as follows: \"Feedback: {{write a feedback for criteria}} [RESULT] {{an integer number between 1 and 5}}\"
4. Please do not generate any other opening, closing, and explanations. Be sure to include [RESULT] in your output.

###The instruction to evaluate:
{instruction}

###Response to evaluate:
{response}

###Reference Answer (Score 5):
{reference_answer}

###Score Rubrics:
[Is the response correct, accurate, and factual based on the reference answer?]
Score 1: The response is completely incorrect, inaccurate, and/or not factual.
Score 2: The response is mostly incorrect, inaccurate, and/or not factual.
Score 3: The response is somewhat correct, accurate, and/or factual.
Score 4: The response is mostly correct, accurate, and factual.
Score 5: The response is completely correct, accurate, and factual.

###Feedback:"""

from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import SystemMessage


evaluation_prompt_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are a fair evaluator language model."),
        HumanMessagePromptTemplate.from_template(EVALUATION_PROMPT),
    ]
)

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.chat_models import ChatOpenAI

eval_chat_model = ChatOpenAI(model="gpt-4-1106-preview", temperature=0)
evaluator_name = "GPT4"


def evaluate_answers(
    answer_path: str,
    eval_chat_model,
    evaluator_name: str,
    evaluation_prompt_template: ChatPromptTemplate,
) -> None:
    """Evaluates generated answers. Modifies the given answer file in place for better checkpointing."""
    answers = []
    if os.path.isfile(answer_path):  # load previous generations if they exist
        answers = json.load(open(answer_path, "r"))

    for experiment in tqdm(answers):
        if f"eval_score_{evaluator_name}" in experiment:
            continue

        eval_prompt = evaluation_prompt_template.format_messages(
            instruction=experiment["question"],
            response=experiment["generated_answer"],
            reference_answer=experiment["true_answer"],
        )
        eval_result = eval_chat_model.invoke(eval_prompt)
        feedback, score = [item.strip() for item in eval_result.content.split("[RESULT]")]
        experiment[f"eval_score_{evaluator_name}"] = score
        experiment[f"eval_feedback_{evaluator_name}"] = feedback

        with open(answer_path, "w") as f:
            json.dump(answers, f)

# %%
if not os.path.exists("./output"):
    os.mkdir("./output")

for chunk_size in [200]:  # add other chunk sizes (in tokens) as needed
    for embeddings in ["jina-embeddings-v2-base-en"]:  # Add other embeddings as needed
        for rerank in [True, False]:
            settings_name = f"chunk:{chunk_size}_embeddings:{embeddings.replace('/', '~')}_rerank:{rerank}_reader-model:{READER_MODEL_NAME.replace('/', '~')}"
            output_file_name = f"./output/rag_{settings_name}.json"

            print(f"Running evaluation for {settings_name}:")

            run_rag_tests(
                eval_dataset=eval_dataset,
                llm=READER_LLM,
                output_file=output_file_name,
                reranker=RERANKER,
                verbose=False,
                test_settings=settings_name,
            )

            print("Running evaluation...")
            evaluate_answers(
                output_file_name,
                eval_chat_model,
                evaluator_name,
                evaluation_prompt_template,
            )
# Out:
# Running evaluation for chunk:200_embeddings:jina-embeddings-v2-base-en_rerank:True_reader-model:HuggingFaceH4~zephyr-7b-beta:
# 100%|██████████| 2/2 [00:00<00:00, 1540.32it/s]
# Running evaluation...
# 100%|██████████| 2/2 [00:16<00:00,  8.15s/it]
# Running evaluation for chunk:200_embeddings:jina-embeddings-v2-base-en_rerank:False_reader-model:HuggingFaceH4~zephyr-7b-beta:
#   0%|          | 0/2 [00:00<?, ?it/s]
# => Retrieving documents...
# => Reranking documents...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.83it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...
#  50%|█████     | 1/2 [02:53<02:53, 173.29s/it]
# => Retrieving documents...
# => Reranking documents...
# 100%|██████████| 1/1 [00:00<00:00, 18.46it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# => Generating answer...
# 100%|██████████| 2/2 [04:46<00:00, 143.11s/it]
# Running evaluation...
# 100%|██████████| 2/2 [00:17<00:00,  8.50s/it]

# %%
import glob

outputs = []
for file in glob.glob("./output/*.json"):
    output = pd.DataFrame(json.load(open(file, "r")))
    output["settings"] = file
    outputs.append(output)
result = pd.concat(outputs)

# %%
result["eval_score_GPT4"] = result["eval_score_GPT4"].apply(lambda x: int(x) if isinstance(x, str) else 1)
result["eval_score_GPT4"] = (result["eval_score_GPT4"] - 1) / 4

# %%
average_scores = result.groupby("settings")["eval_score_GPT4"].mean()
average_scores.sort_values()
# Out:
# settings
# ./output/rag_chunk:200_embeddings:jina-embeddings-v2-base-en_rerank:False_reader-model:HuggingFaceH4~zephyr-7b-beta.json    0.625
# ./output/rag_chunk:200_embeddings:jina-embeddings-v2-base-en_rerank:True_reader-model:HuggingFaceH4~zephyr-7b-beta.json     0.750
# Name: eval_score_GPT4, dtype: float64

# %%
## STREAMLIT
